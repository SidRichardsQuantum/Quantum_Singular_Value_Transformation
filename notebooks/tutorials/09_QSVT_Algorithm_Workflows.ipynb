# %% [markdown]
# # QSVT Algorithm Workflows
#
# This notebook uses the high-level workflow functions in `qsvt.algorithms`.
# Each workflow returns coefficients, scaled operators, polynomial results, and
# classical reference diagnostics in one structured result object.
#
# The examples stay small so the full notebook can run as a release smoke test.
#
# ## Variable definitions
#
# - $H$ is the shared finite tight-binding Hamiltonian and $|\psi\rangle$ is the normalized input state.
# - $A$ is a positive-definite linear-system matrix and $b$ is its right-hand side.
# - `degree` is a polynomial degree, `cutoff` is a spectral threshold, and `time` is the real-time evolution parameter.
# - `eta` is the positive resolvent broadening and `beta` is the inverse-temperature parameter.
# - `finite_qsvt` names a scope backed by an executed finite QSVT circuit; omitted scalable application layers remain explicit.

# %%
from __future__ import annotations

import numpy as np
import matplotlib.pyplot as plt

from qsvt.algorithms import (
    ground_state_filtering_workflow,
    linear_system_workflow,
    singular_value_pseudoinverse_workflow,
    resolvent_workflow,
    spectral_density_workflow,
    thermal_gibbs_workflow,
)
from qsvt.hamiltonians import tight_binding_chain
from qsvt.stable import hamiltonian_simulation_workflow

np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# ## Shared Toy Hamiltonian
#
# A four-site tight-binding chain gives a compact spectrum but still supports
# filtering, real-time evolution, resolvents, spectral density, and thermal
# weights.

# %%
H = tight_binding_chain(
    4,
    hopping=0.8,
    onsite=[-0.2, 0.1, 0.35, 0.7],
)
state = np.array([1.0, 0.25, -0.1, 0.4], dtype=float)
state = state / np.linalg.norm(state)
source = np.array([1.0, 0.0, 0.0, 0.0], dtype=float)

evals = np.linalg.eigvalsh(H)
print("Eigenvalues:", evals)
# Out:
# Eigenvalues: [-1.1405 -0.258   0.7399  1.6086]

# %% [markdown]
# ## Linear System Workflow
#
# The linear-system workflow rescales a positive-definite matrix, designs a
# positive inverse polynomial, and compares the polynomial solution with the exact
# classical solve.

# %%
A = np.array(
    [
        [2.6, 0.25, 0.0, 0.0],
        [0.25, 2.2, 0.2, 0.0],
        [0.0, 0.2, 1.8, 0.15],
        [0.0, 0.0, 0.15, 1.5],
    ],
    dtype=float,
)
rhs = np.array([1.0, -0.5, 0.25, 0.75], dtype=float)
linear = linear_system_workflow(
    A,
    rhs,
    degree=7,
    num_points=301,
    bounded_num_points=601,
    attempt_synthesis=False,
    apply_qsvt=False,
)
print("Polynomial residual:", linear.polynomial_residual_norm)
print("Relative error:", linear.polynomial_relative_error)
# Out:
# Polynomial residual: 0.06293240930104763
# Relative error: 0.04364138573090729

# %% [markdown]
# ## Singular-Value Pseudoinverse Workflow
#
# The singular-value workflows handle rectangular or non-Hermitian matrices through dense SVD validation. This small least-squares example applies a truncated pseudoinverse polynomial above a normalized singular-value cutoff.

# %%
forward = np.array(
    [
        [1.0, 0.2, 0.0],
        [0.3, 0.9, 0.1],
        [0.0, 0.25, 0.7],
        [0.0, 0.0, 0.35],
    ],
    dtype=float,
)
measurement = np.array([1.0, 0.6, 0.2, 0.05], dtype=float)
svd_inverse = singular_value_pseudoinverse_workflow(
    forward,
    measurement,
    cutoff=0.2,
    degree=12,
    num_points=401,
)
print("SVD pseudoinverse residual:", svd_inverse.residual_norm)
print("SVD pseudoinverse relative error:", svd_inverse.solution_relative_error)
# Out:
# SVD pseudoinverse residual: 0.2565206117883862
# SVD pseudoinverse relative error: 0.20781082242140675

# %% [markdown]
# ## Physics Workflows
#
# The remaining workflows share the same Hamiltonian and state. Each exposes a
# single diagnostic that can be tracked across parameter choices. Hamiltonian
# simulation additionally carries an acceptance report. It coherently combines
# the cosine and sine QSVT sequences, records selector postselection and circuit
# resources, and can reach full acceptance for its finite-QSVT scope.

# %%
ground = ground_state_filtering_workflow(
    H,
    state,
    degree=8,
    width=0.35,
    num_points=301,
)
real_time = hamiltonian_simulation_workflow(
    H,
    state,
    time=0.8,
    degree=8,
    num_points=301,
)
green = resolvent_workflow(
    H,
    omega=0.1,
    eta=0.35,
    degree=8,
    source=source,
    num_points=301,
)
centers = np.linspace(evals[0], evals[-1], 25)
density = spectral_density_workflow(
    H,
    centers,
    width=0.35,
    degree=8,
    state=state,
    num_points=301,
)
thermal = thermal_gibbs_workflow(
    H,
    beta=0.9,
    degree=8,
    state=state,
    num_points=301,
)

summary = {
    "Ground state overlap [probability]": ground.ground_state_overlap,
    "Ground filter state error": ground.reference_state_error,
    "Hamiltonian state error": real_time.state_relative_error,
    "Resolvent response error": green.response_relative_error,
    "Spectral density error": density.trace_density_error,
    "Thermal density error": thermal.density_matrix_relative_error,
}
for key, value in summary.items():
    print(f"{key}: {value:.3e}")

real_time_acceptance = real_time.as_report()["acceptance"]
print(
    "Hamiltonian acceptance: "
    f"{real_time_acceptance['status']} "
    f"(scope={real_time_acceptance['scope']}, "
    f"full_qsvt={real_time_acceptance['full_qsvt_acceptance']})"
)
for check in real_time_acceptance["checks"]:
    if check["required_for_full_qsvt"] and not check["passed"]:
        print(f"Full-QSVT gap: {check['id']} — {check['description']}")
# Out:
# Ground state overlap [probability]: 9.855e-01
# Ground filter state error: 1.252e-03
# Hamiltonian state error: 3.953e-08
# Resolvent response error: 1.695e-01
# Spectral density error: 4.670e-02
# Thermal density error: 6.412e-08
# Hamiltonian acceptance: accepted_for_stated_scope (scope=finite_qsvt, full_qsvt=True)

# %% [markdown]
# ## Visual Diagnostic
#
# Plotting the spectral-density workflow makes the reference comparison visible
# without inspecting the full report payload.

# %%
fig, ax = plt.subplots(figsize=(6.5, 3.5))
ax.plot(density.centers, density.reference_trace_density, label="reference")
ax.plot(density.centers, density.polynomial_trace_density, "--", label="polynomial")
ax.scatter(
    evals, np.zeros_like(evals), marker="|", s=120, color="black", label="spectrum"
)
ax.set_xlabel("energy")
ax.set_ylabel("Gaussian trace density")
ax.set_title("spectral-density workflow")
ax.legend(loc="best")
fig.tight_layout()

# %% [markdown]
# ## Report Payloads
#
# Every workflow result has an `as_report()` method. These reports can be passed
# to `qsvt.reports.report_to_jsonable`, saved as JSON, or used as release
# artifacts.

# %%
report = thermal.as_report()
print(report["mode"])
print("report keys [count/list]:", sorted(report)[:8], "...")
assert all(np.isfinite(value) for value in summary.values() if value is not None)
# Out:
# thermal-gibbs-workflow
# report keys [count/list]: ['beta', 'coeffs', 'degree', 'density_matrix_relative_error', 'implementation_kind', 'mode', 'operator_relative_error', 'polynomial_boltzmann_operator'] ...
